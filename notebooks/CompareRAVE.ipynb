# %%
# %matplotlib inline

# %%
raveF = Table.read('/data/jls/GaiaDR2/spectro/RAVE_DR5_distances_FINEGRID__withPRIOR.hdf5')

# %%
plt.plot(rave['b_1'],rave['log10_av_err_1'],'.',ms=2)
plt.semilogy()
# plt.plot(rave['b'],rave['log10_av_err'],'.',ms=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-976b653a6be2> in <module>()
# ----> 1 plt.plot(rave['b_1'],rave['log10_av_err_1'],'.',ms=2)
#       2 plt.semilogy()
#       3 # plt.plot(rave['b'],rave['log10_av_err'],'.',ms=2)
#
# /home/jls/.local/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#    1220     def __getitem__(self, item):
#    1221         if isinstance(item, six.string_types):
# -> 1222             return self.columns[item]
#    1223         elif isinstance(item, (int, np.integer)):
#    1224             return self.Row(self, item)
#
# /home/jls/.local/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#     107         """
#     108         if isinstance(item, six.string_types):
# --> 109             return OrderedDict.__getitem__(self, item)
# ...

# %%
plt.plot(raveF['log10_age'],raveF['log10_age_err'],'.',ms=2)
plt.semilogy()
# Out:
# []

# %%
from astropy.table import Table, join
rave = Table.read('/data/jls/GaiaDR2/spectro/RAVE_DR5_distances_withPRIOR_MASTER.hdf5')

# %%
m['raveid']=m['RAVEID']

# %%
m = m.merge(raveinput,on='raveid')

# %%
plt.plot(m.log_Av[m.eage<2e9],m.log10_av[m.eage<2e9],'.',ms=4)
# xx = np.linspace(-2.,0.)
# plt.plot(xx,xx*3.1/2.8)
# plt.ylim(-0.3,)
# plt.plot(m.logg_err_1,m.logg_err_2,'.',ms=4)
# plt.semilogy()
# plt.semilogx()

# %%
np.count_nonzero(raveinput['Z_err']<1e-2)
# Out:
# 12848

# %%
from matplotlib.colors import LogNorm

# %%
plt.plot(np.log10(raveinput['log10_age_err']),raveinput['log10_age'],'.',ms=2)
plt.axvline(np.log10(0.02),color='k')
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':

# %%
plt.plot(apogee['log10_age'],np.log10(apogee['log10_age_err']),'.',ms=2);
plt.axhline(np.log10(0.02))
plt.ylim(-5.,0.)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# (-5.0, 0.0)

# %%
plt.hist2d(apogee['log10_teff'][(apogee['log10_age_err']<0.07)&(apogee['log10_age']>0.)],
           apogee['logg'][(apogee['log10_age_err']<0.07)&(apogee['log10_age']>0.)],
           range=[[3.4,3.9],[-1,6.]],bins=40,norm=LogNorm());
g = np.genfromtxt('/data/jls/isochrones/PARSEC_Gaia/grid/gaia_0.003.dat')
plt.plot(g.T[5][g.T[1]==9.5],g.T[6][g.T[1]==9.5],'.',ms=5)
plt.plot(g.T[5][g.T[1]==9.55],g.T[6][g.T[1]==9.55],'.',ms=5)

# %%
plt.hist2d(np.log10(raveinput['teff'])[(raveinput['flag']==1)],
           raveinput['logg_x'][(raveinput['flag']==1)],
           range=[[3.4,3.9],[-1,6.]],bins=20,norm=LogNorm());
g = np.genfromtxt('/data/jls/isochrones/PARSEC_Gaia/grid/gaia_0.207.dat')
plt.plot(g.T[5][g.T[1]==9.5],g.T[6][g.T[1]==9.5],'.',ms=5)
plt.plot(g.T[5][g.T[1]==9.55],g.T[6][g.T[1]==9.55],'.',ms=5)

# %%
plt.hist2d(np.log10(raveinput['Z_err']),raveinput['logg_y'],
           range=[[-10.,1.],[-3.,6.]],bins=30,norm=LogNorm());
# plt.semilogx()
# plt.semilogy()
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':

# %%
plt.hist(raveinput.eTeff_K/raveinput.Teff_N_K,range=[0.,.04]);

# %%
np.count_nonzero(m.log10_age_err_1<1e-2)
# Out:
# 888

# %%
plt.hist((m.log10_age_err_1*np.log(10.))[(m.eage<2e9)&(m.age<4e9)],range=[0.,0.7],histtype='step',bins=40)
plt.hist((m.eage/m.age)[(m.eage<2e9)&(m.age<4e9)],range=[0.,0.7],histtype='step',bins=40);

# %%
# plt.plot(m.eage/m.age,np.log10(m.age)-9.,'.',ms=2)
# plt.ylim(8.5,10.1)
# plt.xlim(0.,2)
# plt.plot(m.eage,m.age,'.',ms=2)
plt.plot(m.log10_age_err_1*np.log(10.),m.log10_age_1,'.',ms=2)
plt.plot(m.eage/m.age,np.log10(m.age)-9.,'.',ms=2)

plt.ylim(-0.5,1.2)
plt.xlim(0.,2.)
# Out:
# (0.0, 2.0)

# %%
# plt.plot(m.eage,m.age,'.',ms=2)
plt.plot(m.log10_age_err_1*np.log(10.),m.log10_age_1,'.',ms=2)
plt.ylim(-0.5,1.2)
plt.xlim(0.,2.)
# Out:
# (0.0, 2.0)

# %%
raveinput = pd.read_hdf('/local/scratch_2/jls/RAVE_input.hdf5')

# %%
plt.hist(raveinput['e_fe_h'],range=[0.,.2]);

# %%
# !ls -lt /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST_PPP.hdf5
# Out:
# -rw-r--r-- 1 jls jls 6118387 Jun 15 13:31 /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST_PPP.hdf5

# %%
raveT = Table.read('/local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST_PPP.hdf5')

# %%
rave = join(rave,raveT,keys='raveid')

# %%
np.count_nonzero(rave['flag_2'])

# %%
plt.hist(rave['flag_1']-rave['flag_2'],range=[-4.,4.],histtype='step');
plt.semilogy()
# Out:
# []

# %%
plt.plot(rave['l_2'][rave['Z_err_2']<1e-3],
         rave['b_2'][rave['Z_err_2']<1e-3],'.',ms=5)

# %%
raveinput = raveinput.merge(raveT.to_pandas(),on='raveid')

# %%
# plt.plot(raveinput['log10_age_err_1'][raveinput['Z_err_2']>0.],
#          raveinput['par_err_1'][raveinput['Z_err_2']>0.],'.',ms=5)
plt.plot(raveinput['Z_err_2'][raveinput['Z_err_2']>0.],
         raveinput['par_err_2'][raveinput['Z_err_2']>0.],'.',ms=5)
plt.semilogx()
plt.semilogy()
# Out:
# []

# %%
plt.hist(raveinput['log10_teff_err_2'],range=[0.,0.001])
# Out:
# (array([230., 107., 107.,  70.,  76.,  76.,  70.,  58.,  78.,  56.]),
#  array([0.    , 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007,
#         0.0008, 0.0009, 0.001 ]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(raveinput['l_2'][raveinput['log10_av_err_2']<1e-3],
         raveinput['b_2'][raveinput['log10_av_err_2']<1e-3],'.',ms=5)
# plt.plot(rave['Z_2'],rave['Z_err_2'],'.',ms=5)
# plt.semilogy()

# %%
plt.plot(rave['Z_1'][rave['Z_err_2']>0.],
         rave['Z_err_1'][rave['Z_err_2']>0.],'.',ms=5)
plt.plot(rave['Z_2'],rave['Z_err_2'],'.',ms=5)
plt.semilogy()
plt.ylim(1e-3,)
# Out:
# (0.001, 2.3208891050391385)

# %%
np.count_nonzero(rave['Z_err_2']<1e-3)
# Out:
# 111

# %%
np.count_nonzero((rave['flag_2']==1)&(rave['flag_1']==0))
# Out:
# 11

# %%
plt.plot(rave['Z_err_1'],rave['Z_err_2'],'.',ms=5)
plt.semilogy()
plt.semilogx()
# Out:
# []

# %%
raveinput = pd.read_hdf('/data/jls/GaiaDR2/spectro/RAVE_input_MASTER.hdf5')

# %%
# !ls -lt /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5
# Out:
# -rw-r--r-- 1 jls jls 148192809 Jun 13 09:13 /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5

# %%
rave_T = Table.read('/local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5')

# %%
np.count_nonzero((rave_T['flag']>=0)&(rave['flag']==0)), np.count_nonzero((rave_T['flag']>=0)&(rave_T['flag']==0))
# Out:
# (393698, 389539)

# %%
plt.plot(rave_T['flag'][rave_T['flag']>=0],rave['flag'][rave_T['flag']>=0],'.')

# %%
np.count_nonzero(rave_T['flag']==1)
# Out:
# 1647

# %%
np.count_nonzero(rave_T['flag']==3),np.count_nonzero(rave['flag'][rave_T['flag']>=0]==3)
# Out:
# (307, 313)

# %%
plt.hist(rave['logg'][(rave['log10_age_err']<0.2)&(rave['flag']==0)],histtype='step',bins=30);
plt.hist(rave['logg'][(rave['log10_age_err']<0.4)&(rave['flag']==0)],histtype='step',bins=30);

# %%
plt.plot(rave['log10_teff'],rave['logg'],'.',ms=1)
# plt.plot(rave_T['log10_teff'],rave_T['logg'],'.',ms=1)
plt.xlim(3.7,3.8)
plt.ylim(3.,4.)
# Out:
# (3.0, 4.0)

# %%
plt.hist(rave['log10_age'],range=[-3.,1.4],normed=True,histtype='step',lw=2,bins=40)
plt.hist(rave_T['log10_age'],range=[-3.,1.4],normed=True,histtype='step',lw=2,bins=40)
plt.semilogy()
# Out:
# []

# %%
from plotting_general import running_median

# %%
r = running_median(rave['z'][rave['log10_age_err']<0.2],
                   np.power(10.,rave['log10_age'])[rave['log10_age_err']<0.2])
r2 = running_median(rave_T['z'][rave_T['log10_age_err']<0.2],
                    np.power(10.,rave_T['log10_age'])[rave_T['log10_age_err']<0.2])

# %%
plt.plot(r[0],r[1])
plt.plot(r2[0],r2[1])
plt.ylim(0.,12.)
# Out:
# (0.0, 12.0)

# %%
np.nanmin(rave['log10_av'])
# Out:
# -133.0923943197687

# %%
np.count_nonzero(np.log(np.power(10.,rave['log10_av']))<-5.)
# Out:
# 1734

# %%
plt.hist(np.log10(rave['log10_av_err']),range=[-10.,1.],histtype='step',bins=30);
plt.semilogy()
# Out:
# []

# %%
plt.hist(np.log10(rave['log10_age_err']),range=[-4.,0.],histtype='step',bins=30);
plt.semilogy()
# Out:
# []

# %%
plt.hist2d(rave_T['log10_teff'][(np.log10(rave_T['log10_age_err'])<-1.2)&(rave_T['flag']==0)],
         rave_T['logg'][(np.log10(rave_T['log10_age_err'])<-1.2)&(rave_T['flag']==0)],
          range=[[3.5,4.],[0.,5.]],bins=90);

# %%
plt.hist2d(rave_T['Z'][rave_T['flag']==0],np.log10(rave_T['Z_err'][rave_T['flag']==0]),
           range=[[-2.,0.6],[-8.,0.]],bins=50,norm=LogNorm());

# %%
m = pd.read_csv('/data/jls/RAVEdata/distances_PJM2017.csv.gz')

# %%
plt.hist2d(m.age,m.eage,
          range=[[0.5e9,12.5e9],[0.,6e9]],bins=50);

# %%
rave.sou

# %%
plt.hist(m.elogg_PJM,range=[0.,0.5],histtype='step',lw=2,bins=40);
plt.hist(m.logg_err,range=[0.,0.5],histtype='step',lw=2,bins=40);

# %%
plt.hist(m.eage/m.age/np.log(10.),range=[0.,0.5],histtype='step',lw=2,bins=30);
plt.hist(m.log10_age_err,range=[0.,0.5],histtype='step',lw=2,bins=30);

# %%
plt.hist2d(np.power(10.,m.log10_age)*1e9,m.log10_age_err*np.power(10.,m.log10_age)*np.log(10.)*1e9,
          range=[[0.5e9,12.5e9],[0.,6e9]],bins=50);

# %%
m = m.merge(rave.to_pandas(),right_on='raveid',left_on='RAVEID')

# %%
plt.hist2d(apogee['l'][apogee['flag']==1],apogee['b'][apogee['flag']==1],bins=50,norm=LogNorm());

# %%
plt.hist2d(rave['l'][rave['flag']==1],rave['b'][rave['flag']==1],bins=50,norm=LogNorm());

# %%
plt.hist(np.log10(m.eparallax/m.parallax),bins=90,histtype='step',range=[-5.,0.5],normed=True);
plt.hist(np.log10(m.par_err/m.par),
         bins=90,range=[-5.,0.5],histtype='step',normed=True);
plt.hist(np.log10(raveinput['parallax_error']/raveinput['parallax']),
         bins=90,range=[-5.,0.5],histtype='step',normed=True);
plt.xlim(-5.,0.5)
# Out:
# (-5.0, 0.5)

# %%
plt.hist(m.eTeff_PJM,bins=90,histtype='step',range=[0.,200.]);
plt.hist(m.log10_teff_err*np.power(10.,m.log10_teff)*np.log(10.),
         bins=90,range=[0.,200.],histtype='step');
plt.xlim(0.,500.)
# Out:
# (0.0, 500.0)

# %%
np.count_nonzero(m.log10_av_err<1e-3)
# Out:
# 3017

# %%
plt.plot(m.elog_Av,m.log10_av_err*np.log(10.),'.',ms=1)

plt.semilogy()
plt.semilogx()
# Out:
# []

# %%
plt.plot(m.log_Av,m.log10_av,'.',ms=1)
plt.ylim(-2.,1.)
# Out:
# (-2.0, 1.0)

# %%
xx = np.linspace(0.,12.)
plt.plot(np.power(10.,m.log10_age)[m.eage<2e9],m.age[m.eage<2e9]/1e9,'.',ms=1)
plt.plot(xx,xx)

# %%
plt.plot(np.power(10.,m.log10_teff),m.Teff_PJM,'.',ms=1)

# %%
plt.plot(np.power(10.,rave['log10_teff']),rave['logg'],'.',ms=2)
plt.plot(m.Teff_PJM,m.logg_PJM,'.',ms=2)

# %%
plt.plot(np.log10(m.eage),m.age,'.',ms=2)

# %%
plt.hist(np.log10(m.eage),histtype='step',bins=30);

# %%
plt.hist(m.)

# %%
plt.hist2d(rave['log10_age'][rave_T['flag']==0],
           np.log10(rave_T['log10_age_err'][rave_T['flag']==0]),
           range=[[-2.5,1.6],[-8.,0.]],bins=150,norm=LogNorm());

# %% [markdown]
# plt.plot(np.log10(apogee['log10_av_err']*np.log(10.)),apogee['l'],'.',ms=1)

# %%
plt.plot(np.log10(rave['log10_av_err']*np.log(10.)),rave['l'],'.',ms=1)

# %%
apogeeI = pd.read_hdf('/data/jls/GaiaDR2/spectro/APOGEE_input_MASTER.hdf5')

# %%
apogee = Table.read('/data/jls/GaiaDR2/spectro/APOGEE_distances_withPRIOR_MASTER.hdf5')

# %%
plt.plot(apogee['Z'],apogee['Z_err'],'.',ms=2)
plt.semilogy()
# Out:
# []

# %%
apogeeI = apogeeI.merge(apogee.to_pandas(),on='APOGEE_ID')

# %%
n=plt.hist2d(apogeeI[apogeeI['flag']==0]['J']-apogeeI[apogeeI['flag']==0]['K'],
         apogeeI[apogeeI['flag']==0]['K']-5.*np.log10(100./apogeeI['parallax'])[apogeeI['flag']==0]
            -apogeeI[apogeeI['flag']==0]['AK'],range=[[0.,2.],[2.,6.]],bins=40,cmap=plt.cm.Reds)
plt.contour(n[0])
n2=plt.hist2d(apogeeI[apogeeI['flag']==7]['J']-apogeeI[apogeeI['flag']==7]['K'],
         apogeeI[apogeeI['flag']==7]['K']-5.*np.log10(100./apogeeI['parallax'])[apogeeI['flag']==7]
         -apogeeI[apogeeI['flag']==7]['AK'],range=[[0.,2.],[2.,6.]],bins=40)
plt.ylim(-3.,7.)

# plt.plot(apogeeI[apogeeI['flag']==7]['log10_teff'],apogeeI[apogeeI['flag']==7]['logg'],'.',ms=2)
# Out:
# (-3.0, 7.0)

# %%
plt.imshow(n[0]);
plt.imshow(n2[0],alpha=0.3,cmap=plt.cm.Reds);

# %%
plt.plot(apogee[apogee['flag']==0]['log10_teff'],apogee[apogee['flag']==0]['logg'],'.',ms=2)
plt.plot(apogee[apogee['flag']==7]['log10_teff'],apogee[apogee['flag']==7]['logg'],'.',ms=2)

# %%
plt.hist2d(np.log(np.power(10.,apogee['log10_av'])),
           np.log10(apogee['log10_av_err']),range=[[-5.,3.],[-10.,0.]],bins=40,norm=LogNorm());

# %%
plt.hist(apogee['log10_av_err']*np.log(10.),range=[0.,.2],bins=50);

# %%
plt.plot(apogee['log10_av_err'],apogee['par_err'],'.',ms=2)
plt.semilogy()
plt.semilogx()
# Out:
# []

# %%
plt.plot(rave['log10_teff'][rave['log10_av_err']<1e-3],
         rave['logg'][rave['log10_av_err']<1e-3],'.',ms=2)

# %%
plt.hist2d(apogee['log10_av'][np.abs(apogee['b'])>10./180.*np.pi],
           np.log10(apogee['log10_av_err'])[np.abs(apogee['b'])>10./180.*np.pi],
           bins=40,range=[[-5.,2.],[-8.,2.]],norm=LogNorm());

# %%
plt.plot(apogee['l'][np.log10(apogee['log10_av_err'])<-4.],
         apogee['b'][np.log10(apogee['log10_av_err'])<-4.],'.',ms=2)

# %%
plt.plot(rave_T['l'][np.log10(rave_T['log10_av_err'])<-4.],
         rave_T['b'][np.log10(rave_T['log10_av_err'])<-4.],'.',ms=2)

# %%
plt.plot(np.log10(rave_T['log10_av_err']),rave_T['b'],'.',ms=1)

# %%
plt.hist(rave_T['log10_av_err'],range=[0.,0.4])
# Out:
# (array([128397., 148050.,  80337.,  17596.,   4635.,   2340.,   1380.,
#            816.,    584.,    410.]),
#  array([0.  , 0.04, 0.08, 0.12, 0.16, 0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 ]),
#  <a list of 10 Patch objects>)

# %%
np.count_nonzero(np.log10(rave_T['log10_av_err'])<-3.)
# Out:
# 12605

# %%
plt.plot(np.log10(apogee['log10_av_err']),apogee['log10_av'],'.',ms=1)
plt.semilogy()
plt.ylim(0.1,)
# Out:
# (0.1, 1.8935566967545814)

# %%
plt.hist(np.log10(apogee['log10_av_err']*np.log(10.)),range=[-5.,0.5],histtype='step',bins=30);
plt.semilogy()
# Out:
# []

# %%
plt.hist(np.log10(rave['log10_av_err']*np.log(10.)),range=[-5.,0.5],histtype='step',bins=30);
plt.semilogy()
# Out:
# []

# %%
plt.hist2d(rave['log10_age'],np.log(np.power(10.,rave['log10_av'])),
           bins=40,range=[[-3.,1.5],[-10.,3.]],norm=LogNorm())
plt.ylim(-10.,)
# Out:
# (-10.0, 3.0)

# %%
xx = np.linspace(0.,12.5)
plt.hist2d(np.power(10.,rave['log10_age'])[rave['flag']==0],
           np.power(10.,rave_T['log10_age'])[rave['flag']==0],
           bins=30,range=[[0.,13.],[0.,13.]])
plt.plot(xx,xx)

# %%
from matplotlib.colors import LogNorm
plt.hist2d(rave['log10_teff'][(rave['log10_age_err']<0.25/np.log(10.))&(rave['flag']==0)],
        rave['logg'][(rave['log10_age_err']<0.25/np.log(10.))&(rave['flag']==0)],bins=80,range=[[3.4,3.9],[3.,5.]]);

# %%
plt.plot(rave_T['log10_teff'][rave_T['log10_age_err']<0.05],
        rave_T['logg'][rave_T['log10_age_err']<0.05],'.',ms=2)

# %%
raveTT = Table.read('/local/scratch_2/jls/RAVE_')

# %%
plt.hist(rave['log10_age_err']*2.3,range=[0.,1.],bins=40,histtype='step',normed=True)
plt.hist(rave_T['log10_age_err']*2.3,range=[0.,1.],bins=40,histtype='step',normed=True);

# %%
plt.plot(rave['log10_age_err'],rave_T['log10_age_err'],'.',ms=1)
plt.axhline(0.1)
plt.axvline(0.1)
plt.semilogy()
plt.semilogx()
plt.xlim(1e-3,)
plt.ylim(1e-3,)
# Out:
# (0.001, 22.348649887975764)

# %%
np.count_nonzero((raveONinput['qc'])&(raveONinput['r_chi_sq']>3.))
# Out:
# 0

# %%
print

# %%
plt.hist(raveP['log10_teff_err']*np.log(10.),range=[0.,0.03],histtype='step',bins=40);
plt.hist(raveinput['e_teff']/raveinput['teff'],range=[0.,0.03],histtype='step',bins=40);

# %%
plt.plot(raveP['log10_teff'],raveP['logg'],'.',ms=2)
plt.plot(np.log10(raveinput['teff']),raveinput['logg'],'.',ms=2)

# %%
plt.hist(raveP['Z']-raveinput['fe_h'],range=[-.1,.1],bins=40);

# %%
np.count_nonzero((~raveONinput['qc'])&(raveONinput['fe_h']==raveONinput['fe_h']))
# Out:
# 10947

# %%
rave.colnames
# Out:
# ['raveid',
#  'source_id',
#  'dm',
#  'dm_err',
#  'dist',
#  'dist_err',
#  'par',
#  'par_err',
#  'log10_age',
#  'log10_age_err',
#  'mass',
#  'mass_err',
#  'Z',
#  'Z_err',
#  'log10_av',
#  'log10_av_err',
#  'log10_teff',
#  'log10_teff_err',
#  'logg',
#  'logg_err',
#  'dm_log10age_corr',
#  'log10age_Z_corr',
#  'dm_Z_corr',
#  'l',
#  'b',
#  's',
#  'vlos',
#  'mu_l',
#  'mu_b',
#  'R',
#  'phi',
#  'z',
#  'vR',
#  'vphi',
#  'vz',
#  'JR',
#  'Lz',
#  'Jz',
#  'Rc',
#  's_err',
#  'vlos_err',
#  'mu_l_err',
#  'mu_b_err',
#  'R_err',
#  'phi_err',
#  'z_err',
#  'vR_err',
#  'vphi_err',
#  'vz_err',
#  'JR_err',
#  'Lz_err',
#  'Jz_err',
#  'Rc_err',
#  'flag']

# %%
raveinput = pd.read_hdf('/data/jls/GaiaDR2/spectro/RAVE_input_MASTER.hdf5')

# %%
np.count_nonzero(raveinput.G!=raveinput.G)
# Out:
# 1202

# %%
from astropy.table import Table
rave = Table.read('/data/jls/GaiaDR2/spectro/RAVE_DR5_distances_withPRIOR_MASTER.hdf5')

# %%
raveP = Table.read('/local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD.hdf5')
# Out:
# /home/jls/.local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
raveP

# %%
np.count_nonzero(rave['flag']==1)
# Out:
# 1358

# %%
np.count_nonzero(raveP['flag']==1)
# Out:
# 2105

# %%
# !ls -lt /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5
# Out:
# -rw-r--r-- 1 jls jls 3994089 Jun 12 13:57 /local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5

# %%
raveT = Table.read('/local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_TEST.hdf5')

# %%
raveT = pd.merge(raveP.to_pandas(),raveT.to_pandas(),on='raveid')

# %%
len(raveT)
# Out:
# 10000

# %%
plt.hist(raveT.log10_age_err_x-raveT.log10_age_err_y,range=[-1.,1.],bins=40,histtype='step');
plt.semilogy()
# Out:
# []

# %%
plt.plot(raveT.log10_teff_err_x,raveT.log10_teff_err_y,'.',ms=2)

# %%
plt.scatter(raveT.log10_teff_y,raveT.logg_y,c=raveT.log10_age_y-raveT.log10_age_x,vmin=-.1,vmax=.1,s=4)
plt.colorbar()
plt.ylim(3.5,5.)
# Out:
# (3.5, 5.0)

# %%
# plt.hist(rave['log10_age_err'],range=[0.,1.],normed=True,histtype='step',bins=50)
plt.hist(raveT['s_y'],range=[0.,30.],normed=True,histtype='step',bins=50);
plt.hist(raveT['s_x'],range=[0.,30.],normed=True,histtype='step',bins=50);
plt.semilogy()
# Out:
# []

# %%
# plt.hist(rave['log10_age_err'],range=[0.,1.],normed=True,histtype='step',bins=50)
plt.hist(raveP['log10_age_err'],range=[0.,1.],normed=True,histtype='step',bins=50);
plt.hist(rave['log10_age_err'],range=[0.,1.],normed=True,histtype='step',bins=50);
# plt.semilogy()

# %%
# plt.hist(np.power(10.,rave['log10_age']),range=[1.,13.],normed=True,histtype='step')
plt.hist(np.power(10.,rave['log10_age']),range=[1.,13.],normed=True,histtype='step',bins=50)
plt.hist(np.power(10.,raveP['log10_age']),range=[1.,13.],normed=True,histtype='step',bins=50);

# %%
plt.plot(rave['JR'],raveP['JR'],'.',ms=1)
plt.xlim(0.,1000.)
plt.ylim(0.,1000.)
# Out:
# (0.0, 1000.0)

# %%
plt.plot(np.power(10.,rave['log10_age']),np.power(10.,raveP['log10_age']),'.',ms=1)

# %%
plt.plot(rave['log10_age_err'],raveP['log10_age_err'],'.',ms=1)
xx = np.linspace(0.,0.5)
plt.plot(xx,xx)

# %%
plt.hist(rave['log10_age']-raveP['log10_age'],range=[-1.,1.],bins=50,histtype='step',lw=3);

# %%
# plt.plot(np.power(10.,ravePT['log10_age']),rave['Z'],'.',ms=2)
plt.plot(np.power(10.,raveP['log10_age']),
         raveP['Z'],'.',ms=1)

# %%
# plt.plot(np.power(10.,ravePT['log10_age']),rave['Z'],'.',ms=2)
plt.plot(np.power(10.,rave['log10_age']),
         rave['Z'],'.',ms=1)

# %%
plt.plot(rave['logg'],
         raveP['logg'],'.',ms=1)

# %%
plt.hist(rave['par']-
         raveP['par'],range=[-0.03,0.03],bins=50);

# %%
plt.hist(rave['z']-
         raveP['z'],range=[-0.03,0.03],bins=50);
