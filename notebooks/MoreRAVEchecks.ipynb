# %%
# %matplotlib inline

# %%
raveI2 = pd.read_hdf('/local/scratch_2/jls/RAVE_input.hdf5')

# %%
raveI = pd.read_hdf('/data/jls/GaiaDR2/spectro/RAVE_input_MASTER.hdf5')

# %%
from astropy.table import Table
rave = Table.read('/data/jls/GaiaDR2/spectro/RAVE_DR5_distances_withPRIOR_MASTER.hdf5')
# Out:
# /home/jls/.local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %% [markdown]
# ### Test failure regions

# %%
from matplotlib.colors import LogNorm

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(raveI[rave['flag']==1]['teff'],
          raveI[rave['flag']==1]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(raveI[rave['flag']==7]['teff'],
          raveI[rave['flag']==7]['logg'],bins=40,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(np.power(10.,rave[rave['flag']==7]['log10_teff']),
          rave[rave['flag']==7]['logg'],bins=40,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(raveI[rave['flag']==6]['teff'],
          raveI[rave['flag']==6]['logg'],bins=40,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(np.power(10.,rave[rave['flag']==6]['log10_teff']),
          rave[rave['flag']==6]['logg'],bins=40,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
plt.hist(rave['log10_av'][rave['flag']==0],range=[-3.,2.],histtype='step',normed=True,bins=40);
plt.hist(rave['log10_av'][rave['flag']==6],histtype='step',normed=True,bins=40);

# %%
plt.hist2d(rave['l'][rave['flag']==6],
          rave['b'][rave['flag']==6],bins=40,norm=LogNorm());

# %%
plt.plot(np.log10(raveT['log10_av_err']),np.log10(rave['log10_av_err']),'.',ms=2)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':

# %%
np.count_nonzero(raveT['log10_av_err']<0.01)
# Out:
# 7664

# %%
plt.plot(rave['b'],np.log10(raveT['log10_av_err']*np.log(10.)),'.',ms=1)
plt.axhline(np.log10(0.3),color='k')
# plt.xlim(-2.,2.)
plt.ylim(-3.,)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# (-3.0, 0.5091477073190697)

# %%
np.arange(2,19,2)
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
raveT = Table.read('/local/scratch_2/jls/RAVE_DR5_distances_withPRIOR_BROAD_NEW_SETUP.hdf5')

# %%
n=plt.hist2d(np.power(10.,rave[rave['flag']==0]['log10_teff']),
          rave[rave['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(raveI[raveT['flag']==1]['teff'],
          raveI[raveT['flag']==1]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10
