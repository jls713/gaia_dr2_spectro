# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
inputsF = pd.read_hdf('/data/jls/GaiaDR2/spectro/APOGEE_TGAS_test.hdf5')

# %%
plt.plot(inputsF.J-inputsF.K,inputsF.J-5.*np.log10(100./inputsF.parallax),'.',ms=2)

# %%
inputs = pd.read_hdf('/data/jls/GaiaDR2/spectro/APOGEE_TGAS_test.hdf5').sample(100, random_state=52)

# %%
from astropy.table import Table
results = Table.read('/data/jls/GaiaDR2/spectro/APOGEETGAS_TEST_distances_random100.hdf5')
resultsG = Table.read('/data/jls/GaiaDR2/spectro/APOGEETGAS_TEST_distances_random100_G.hdf5')

# %%
plt.hist((inputs['parallax']-results['par'])/np.sqrt(inputs['parallax_error']**2+results['par_err']**2), 
         histtype='step', lw=2, bins=15, range=[-4.,4.]);
plt.hist((inputs['parallax']-resultsG['par'])/np.sqrt(inputs['parallax_error']**2+resultsG['par_err']**2), 
         histtype='step', lw=2, bins=15, range=[-4.,4.]);

# %%
plt.hist(results['s']-resultsG['s'],range=[-.2,.2],bins=20, histtype='step');

# %%
plt.hist(results['log10_av']-resultsG['log10_av'],range=[-.1,.1],bins=20, histtype='step');

# %%
plt.hexbin(results['log10_teff'], results['logg'], C=results['dm']-resultsG['dm'], gridsize=20, cmap=plt.cm.viridis);
plt.colorbar()

# %%
plt.hist(results['logg']-resultsG['logg'],range=[-.1,.1],bins=20, histtype='step');

# %%
plt.hist(results['log10_age']-resultsG['log10_age'],range=[-1.,1.],bins=20, histtype='step');

# %%
plt.plot(np.power(10.,results['log10_age']), results['Z'], '.')
plt.plot(np.power(10.,resultsG['log10_age']), resultsG['Z'], '.')

# %%
plt.plot(inputs['mass'],resultsG['log10_age'],'.')
plt.plot(inputs['mass'],results['log10_age'],'.')

# %%
r = Table.read('/data/jls/GaiaDR2/spectro/APOGEETGAS_TEST_distancesTOP100.hdf5')
ri = pd.read_hdf('/data/jls/GaiaDR2/spectro/APOGEE_TGAS_test.hdf5')[:100]

# %%
plt.plot(ri['mass'],np.power(10.,r['log10_age']),'.')

# %%
plt.plot(resultsG['s']-results['s'],inputs.eJ,'.')

# %%
plt.plot(inputs.J-inputs.K,inputs.J-results['dm'],'.',ms=5)

# %%
plt.plot(inputs.G-inputs.K,inputs['teff'],'.',ms=5)

# %%
plt.plot(inputs.J-inputs.H,inputs.G-results['dm'],'.',ms=5)
plt.plot(inputs.J-inputs.H,inputs.G-resultsG['dm'],'.',ms=10)

# %%
plt.plot(inputs.J-resultsG['dm'],inputs.G-resultsG['dm'],'.',ms=10)

# %%
plt.plot(inputs.J-inputs.K,inputs.G-resultsG['dm'],'.',ms=10)
plt.plot(inputs.J-inputs.K,inputs.K-results['dm'],'.',ms=10)
plt.plot(inputs.J-inputs.K,inputs.K-resultsG['dm'],'.',ms=10)
plt.plot(inputs.J-inputs.K,inputs.G-results['dm'],'.',ms=10)

# %%
plt.plot(inputs.G-inputs.K,results['log10_teff'],'.',ms=10)
plt.plot(inputs.G-inputs.K,resultsG['log10_teff'],'.',ms=10)
plt.plot(inputs.J-inputs.K,resultsG['log10_teff'],'.',ms=10)

# %%
plt.plot(inputs.G-results['dm'],inputs.K-results['dm'],'.')
plt.plot(p.T[0],p.T[1])
plt.xlim(-4.,4.)
plt.ylim(-6.,3.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8aa5d4c1e851> in <module>()
#       1 plt.plot(inputs.G-results['dm'],inputs.K-results['dm'],'.')
# ----> 2 plt.plot(p.T[0],p.T[1])
#       3 plt.xlim(-4.,4.)
#       4 plt.ylim(-6.,3.)
#
# NameError: name 'p' is not defined

# %%
p = np.genfromtxt('../../../code/gaia_sprint/isochrone/tmp')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-18-2b99c3045f23> in <module>()
# ----> 1 p = np.genfromtxt('../../../code/gaia_sprint/isochrone/tmp')
#
# /home/jls/.local/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1687             fname = str(fname)
#    1688         if isinstance(fname, basestring):
# -> 1689             fhd = iter(np.lib._datasource.open(fname, 'rt', encoding=encoding))
#    1690             own_fhd = True
#    1691         else:
#
# /home/jls/.local/lib/python2.7/site-packages/numpy/lib/_datasource.pyc in open(path, mode, destpath, encoding, newline)
#     258
# ...
