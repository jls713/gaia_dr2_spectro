# %%
# %matplotlib inline

# %%
apogeeI = pd.read_hdf('/data/jls/GaiaDR2/spectro/APOGEE_input.hdf5')

# %%
from utils import read_fits_to_pandas
vac = read_fits_to_pandas('/data/jls/apogee/apogee_distances-DR14.fits')

# %%
vacI = vac.merge(apogeeI,on='APOGEE_ID')

# %%
vacM = vac.merge(apogee.to_pandas(),on='APOGEE_ID')

# %%
plt.plot(vacI.BPG_meandist,1./vacI.parallax,'.',ms=1)
plt.xlim(0.,20.)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
plt.hist(np.log10(vacM.BPG_AVstd),range=[-5.,1.],histtype='step',bins=30);
plt.hist(np.log10(vacM.log10_av_err*np.power(10.,vacM.log10_av)*np.log(10.)),
         range=[-5.,1.],histtype='step',bins=30);
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
plt.hist(np.log10(vacI.parallax_error/vacI.parallax),range=[-5.,1.],histtype='step',bins=30)
plt.hist(np.log10(vacM.dist_err/vacM.dist),range=[-5.,1.],histtype='step',bins=30);
# plt.hist(np.log10(vacM.BPG_diststd/vacM.BPG_meandist),range=[-5.,1.],histtype='step',bins=30);
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in log10
#   if __name__ == '__main__':

# %%
plt.plot(vacM.BPG_meandist,vacM.NAOC_dist,'.',ms=0.3)
plt.xlim(0.,20.)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
plt.plot(vac.BPG_meandist,vac.NICE_dist,'.',ms=2)
plt.xlim(0.,20.)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
plt.plot(vac.BPG_meandist,vac.NAOC_dist,'.',ms=2)
plt.xlim(0.,20.)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
plt.plot(vacM.BPG_meanAV,vacM.NAOC_AK,'.',ms=1)
plt.semilogx()
plt.semilogy()
# plt.xlim(0.01,)
# plt.ylim(-2.,)
# Out:
# []

# %%
plt.plot(vacM.BPG_meanAV,vacM.log10_av,'.',ms=1)
plt.semilogx()
plt.xlim(0.01,)
plt.ylim(-2.,)
# Out:
# (-2.0, 1.6909462488032143)

# %%
np.count_nonzero(vacM.par_err/vacI.parallax_error>1.3)
# Out:
# 1622

# %%
xx = np.linspace(-5.,5.)
plt.hist((vacM.BPG_meanAV-np.power(10.,vacM.log10_av))/np.sqrt(vacM.BPG_AVstd**2+(np.power(10.,vacM.log10_av)*vacM.log10_av_err*np.log(10.))**2)
                                                                                  ,range=[-5.,5.],bins=50,normed=True);
plt.plot(xx,np.exp(-xx**2/2.)/np.sqrt(2.*np.pi))

# %%
np.count_nonzero(vacM.BPG_diststd>0.)
# Out:
# 210469

# %%
plt.plot(vacI.BPG_meandist[vacI.parallax_error/vacI.parallax<0.1],
         1./vacI.parallax[vacI.parallax_error/vacI.parallax<0.1],'.',ms=1)
# plt.plot(vacM.BPG_meandist[vacI.parallax_error/vacI.parallax<0.2],
#          vacM.dist[vacI.parallax_error/vacI.parallax<0.2],'.',ms=1)
plt.plot(1./vacI.parallax[vacI.parallax_error/vacI.parallax<0.1],
         vacM.dist[vacI.parallax_error/vacI.parallax<0.1],'.',ms=2)
plt.xlim(0.,10.)
plt.ylim(0.,10.)
# Out:
# (0.0, 10.0)

# %%
plt.plot(np.log10(vacM.log10_av_err*np.log(10.)),np.log10(vacM.NAOC_err_AK/vacM.NAOC_AK),'.',ms=1)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':

# %%
plt.plot(vacM.b,np.log10(vacM.log10_av_err*np.log(10.)),'.',ms=2)
plt.plot(vacM.b,np.log10(vacM.NAOC_err_AK/vacM.NAOC_AK),'.',ms=2)
plt.plot(vacM.b,np.log10(vacM.BPG_AVstd/vacM.BPG_meanAV),'.',ms=2)
# plt.ylim(-4.,)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10

# %%
plt.plot(vacM.BPG_AVstd,
         np.power(10.,vacM.log10_av)*vacM.log10_av_err*np.log(10.),'.',ms=1)
plt.semilogy()
plt.semilogx()
plt.xlim(1e-3,)
plt.ylim(1e-3,)
# Out:
# (0.001, 2.296341267616071)

# %%
np.nanstd((vacM.BPG_meandist-vacM.dist))
# Out:
# 5.191968883223336

# %%
plt.hexbin(vacM.log10_teff[vacI.parallax_error/vacI.parallax<.5],
           vacM.logg[vacI.parallax_error/vacI.parallax<.5],
           C=(vacM.dist-vacM.BPG_meandist).values[vacI.parallax_error/vacI.parallax<.5],
           vmin=-.5,vmax=.5,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian,mincnt=5);
plt.colorbar()

# %%
plt.hexbin(vacM.log10_teff[vacI.parallax_error/vacI.parallax<.2],
           vacM.logg[vacI.parallax_error/vacI.parallax<.2],
           C=(1./vacI.parallax-vacM.BPG_meandist).values[vacI.parallax_error/vacI.parallax<.2],
           vmin=-.2,vmax=.2,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian,mincnt=5);
plt.colorbar()

# %%
plt.hexbin(vacM.log10_teff[vacI.parallax_error/vacI.parallax<.5],
           vacM.logg[vacI.parallax_error/vacI.parallax<.5],
           C=(1./vacI.parallax-vacM.BPG_meandist).values[vacI.parallax_error/vacI.parallax<.5],
           vmin=-.5,vmax=.5,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian,mincnt=5);
plt.colorbar()

# %%
plt.hexbin(vacI.teff,vacI.logg,C=(vacM.dist-1./vacI.parallax)[vacI.parallax_error/vacI.parallax<0.3].values,
           vmin=-.2,vmax=.2,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian);
plt.colorbar()

# %%
plt.hexbin(vacI.teff,vacI.logg,C=(vacI.BPG_meandist-1./vacI.parallax)[vacI.parallax_error/vacI.parallax<0.3].values,
           vmin=-1.,vmax=1.,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian);
plt.colorbar()

# %%
plt.hexbin(vacM.log10_teff,vacM.logg,C=(vacM.BPG_meanAV-np.power(10.,vacM.log10_av)),
           vmin=-.4,vmax=.4,cmap=plt.cm.viridis,reduce_C_function=np.nanmedian);
plt.colorbar()

# %%
rangex = [-10.,10.]
plt.hist((vacI.BPG_meandist-1./vacI.parallax),range=rangex,bins=50,histtype='step',lw=4);
plt.hist((vacM.BPG_meandist-vacM.dist),range=rangex,bins=50,histtype='step',lw=4);
plt.hist((vacM.NAOC_dist-vacM.BPG_meandist),range=rangex,bins=50,histtype='step');
plt.hist((vacM.NICE_dist-vacM.BPG_meandist),range=rangex,bins=50,histtype='step');
plt.hist((vacM.NMSU_dist-vacM.BPG_meandist),range=rangex,bins=50,histtype='step');
plt.hist((vacM.NMSU_dist_prior-vacM.BPG_meandist),range=rangex,bins=50,histtype='step');
plt.semilogy()
# Out:
# []

# %%
# xx = np.linspace(-5.,5.)
plt.hist((vacM.BPG_meandist-vacM.dist),range=[-5.,5.],bins=50,normed=True,histtype='step');
plt.hist((vacM.NAOC_dist-vacM.dist),range=[-5.,5.],bins=50,normed=True,histtype='step');
plt.hist((vacM.NICE_dist-vacM.dist),range=[-5.,5.],bins=50,normed=True,histtype='step');
plt.hist((vacM.NMSU_dist-vacM.dist),range=[-5.,5.],bins=50,normed=True,histtype='step');
plt.semilogy()
# plt.plot(xx,np.exp(-xx**2/2.)/np.sqrt(2.*np.pi))
# Out:
# []

# %%
xx = np.linspace(-5.,5.)
plt.hist((vacM.BPG_meanAV-0.96*np.power(10.,vacM.log10_av))/np.sqrt(vacM.BPG_AVstd**2+(np.power(10.,vacM.log10_av)*vacM.log10_av_err*np.log(10.))**2)
                                                                                  ,range=[-5.,5.],bins=50,normed=True);
plt.plot(xx,np.exp(-xx**2/2.)/np.sqrt(2.*np.pi))

# %%
plt.hist(vacM.mass_err/vacI.mass_error,range=[0.,2.],bins=50);

# %%
plt.hist(vacM.par_err/vacI.parallax_error,range=[0.,2.],bins=50);

# %%
plt.hist(np.log10(vacM.par_err),range=[-4.,1.],bins=50);
plt.hist(np.log10(vacI.parallax_error),range=[-4.,1.],bins=50,histtype='step');
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in log10
#   from ipykernel import kernelapp as app

# %%
plt.hist((vacM.par-vacI.parallax),range=[-.2,0.2],bins=50);

# %%
# plt.plot(vacM.NAOC_AK,vacM.NICE_E_JK,'.',ms=1)
plt.plot(vacM.NAOC_AK,np.power(10.,vacM.log10_av),'.',ms=1)
plt.plot(vacM.NAOC_AK,vacM.BPG_meanAV,'.',ms=1)
plt.semilogx()
plt.semilogy()
plt.xlim(0.1,1.)
plt.ylim(0.1,10.)
# Out:
# (0.1, 10.0)

# %%
# plt.plot(vacM.BPG_meandist,vacM.dist,'.',ms=2)
# plt.plot(vacM.NAOC_dist,vacM.dist,'.',ms=2)
# plt.plot(vacM.NICE_dist,vacM.dist,'.',ms=1)
plt.plot(vacM.NMSU_dist_prior,vacM.dist,'.',ms=1)
plt.xlim(0.,20.)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
from astropy.table import Table
apogee = Table.read('/data/jls/GaiaDR2/spectro/APOGEE_distances_withPRIOR_MASTER.hdf5')

# %%
# !ls -lt /local/scratch_2/jls/APOGEE_distances_withPRIOR_BROAD_NEW_SETUP.hdf5
# Out:
# -rw-r--r-- 1 jls jls 9517474 Jun 19 17:43 /local/scratch_2/jls/APOGEE_distances_withPRIOR_BROAD_NEW_SETUP.hdf5

# %%
apogeeS = Table.read('/data/jls/GaiaDR2/spectro/APOGEE_distances_withPRIOR_BROAD.hdf5')

# %%
apogeeS = apogeeS.to_pandas().merge(apogee.to_pandas(),on='APOGEE_ID')

# %%
plt.plot(apogeeS['dist_x'],apogeeS['dist_y'],'.',ms=2)
plt.xlim(0.,40.)
plt.ylim(0.,40.)
# Out:
# (0.0, 40.0)

# %%
plt.plot(apogeeS['dist_x'],apogeeS['dist_y'],'.',ms=2)
plt.xlim(0.,40.)
plt.ylim(0.,40.)
# Out:
# (0.0, 40.0)

# %%
# apogeeI = Table.read('/local/scratch_2/jls/APOGEE_distances_withPRIOR_BROAD.d')
apogeeT = Table.read('/local/scratch_2/jls/APOGEE_distances_withPRIOR_BROAD_NEW_SETUP.hdf5')

# %%
len(apogeeT)
# Out:
# 258475

# %%
apogeeT = apogeeT.to_pandas().merge(apogee.to_pandas(),on='APOGEE_ID')[apogeeT['l']==apogeeT['l']]

# %%
np.count_nonzero(apogeeT['l']==apogeeT['l'])
# Out:
# 155030

# %%
np.count_nonzero(apogeeT['flag_x']==1)
# Out:
# 286

# %%
plt.plot(apogeeT['log10_teff'][apogeeT['flag']==6],
         apogeeT['logg'][apogeeT['flag']==6],'.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-325-1c116dc3f957> in <module>()
# ----> 1 plt.plot(apogeeT['log10_teff'][apogeeT['flag']==6],
#       2          apogeeT['logg'][apogeeT['flag']==6],'.')
#
# /home/jls/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/jls/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
plt.hist2d(apogee[apogee['flag']==1]['l'],
          apogee[apogee['flag']==1]['b'],bins=50,range=[[0.,2.*np.pi],[-np.pi/2.,np.pi/2.]],norm=LogNorm());

# %%
# plt.plot(apogeeT['log10_age_y'],np.log10(apogeeT['log10_age_err_y']),'.',ms=5)
plt.plot(apogeeT['log10_age_x'],np.log10(apogeeT['log10_age_err_x']),'.',ms=5)
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
plt.hist2d(np.power(10.,apogeeT[apogeeT['log10_age']<-1.]['log10_teff']),
          apogeeT[apogeeT['log10_age']<-1.]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.hist2d(np.power(10.,apogeeT[apogeeT['log10_age']>-1.]['log10_teff']),
          apogeeT[apogeeT['log10_age']>-1.]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-330-fc2d0a81c8ab> in <module>()
# ----> 1 plt.hist2d(np.power(10.,apogeeT[apogeeT['log10_age']<-1.]['log10_teff']),
#       2           apogeeT[apogeeT['log10_age']<-1.]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
#       3 plt.hist2d(np.power(10.,apogeeT[apogeeT['log10_age']>-1.]['log10_teff']),
#       4           apogeeT[apogeeT['log10_age']>-1.]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
#
# /home/jls/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ...

# %%
# plt.plot(np.power(10.,apogeeT['log10_age_x']),apogeeT['Z_x'],'.',ms=1)
plt.hist2d(np.power(10.,apogeeT['log10_age_x']),apogeeT['Z_x'],bins=30,range=[[0.1,12.5],[-2.,1.]],norm=LogNorm());

# %%
np.count_nonzero((np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])>1.)&(apogeeT['flag_x']==0)&(apogeeT['log10_age_err_x']<0.2))
# Out:
# 1333

# %%
plt.plot(apogeeT['log10_age_x'][np.fabs(apogeeT['log10_age_y']-apogeeT['log10_age_x'])>1.],
           apogeeT['log10_age_y'][np.fabs(apogeeT['log10_age_y']-apogeeT['log10_age_x'])>1.],'.',ms=2)

# %%
plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['log10_age_y']-apogeeT['log10_age_x'])>1.],
           apogeeT['b_x'][np.fabs(apogeeT['log10_age_y']-apogeeT['log10_age_x'])>1.],bins=40,norm=LogNorm());

# %%
plt.hist2d(apogeeS['l_y'][np.fabs(apogeeS['dist_y']-apogeeS['dist_x'])>2.],
           apogeeS['b_y'][np.fabs(apogeeS['dist_y']-apogeeS['dist_x'])>2.],
           bins=40,norm=LogNorm(),range=[[0.,2.*np.pi],[-np.pi/2.,np.pi/2.]]);
# plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.],
#            apogeeT['b_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.]);

# %%
plt.plot(apogeeS['dist_x'].values[fltr],apogeeS['dist_y'].values[fltr],'.')

# %%
plt.hist(np.log10(apogeeT['dist_err_y'])[fltr],range=[-5.,1.],histtype='step',bins=30);
plt.hist(np.log10(apogeeT['dist_err_x'])[fltr],range=[-5.,1.],histtype='step',bins=30);
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
fltr = np.fabs(apogeeT['dist_x']-apogeeT['dist_y'])>1.

# %%
plt.hist2d(apogeeT['log10_teff_x'],apogeeT['logg_x'],bins=30,range=[[3.5,4.],[0.,5.]],norm=LogNorm());

# %%
plt.hist2d(apogeeS['log10_teff_x'],apogeeS['logg_x'],bins=30,range=[[3.5,4.],[0.,5.]],norm=LogNorm());

# %%
plt.hist2d(np.log10(apogeeS['log10_age_err_x']),
           np.log10(apogeeS['log10_age_err_y']),
           range=[[-3.,1.],[-3.,1.]],bins=100,norm=LogNorm());
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
from matplotlib.colors import LogNorm
fltr = (np.fabs(apogeeS['log10_age_err_x'])<0.1)&(apogeeS['flag_x']==0)
plt.hist2d(apogeeS['log10_teff_x'][fltr],apogeeS['logg_x'][fltr],bins=30,range=[[3.5,4.],[0.,5.]],norm=LogNorm());

# %%
from matplotlib.colors import LogNorm
plt.hist2d(apogeeT['log10_teff_x'][fltr],apogeeT['logg_x'][fltr],bins=30,range=[[3.5,4.],[0.,5.]],norm=LogNorm());

# %%
fltr = (np.fabs(apogeeT['b_y'].values)<.5/180.*np.pi)&(apogeeT['flag_x']==0)
plt.errorbar(apogeeT['dist_x'].values[fltr],apogeeT['dist_y'].values[fltr],
             xerr=apogeeT['dist_err_x'].values[fltr],yerr=apogeeT['dist_err_y'].values[fltr],
             fmt='o',ms=3,alpha=0.2)
plt.xlim(0.,30.)
plt.ylim(0.,30.)
# Out:
# (0.0, 30.0)

# %%
fltr = (np.fabs(apogeeS['b_y'].values)<2./180.*np.pi)&(apogeeS['flag_y']==0)
plt.errorbar(apogeeS['dist_x'].values[fltr],apogeeS['dist_y'].values[fltr],
             xerr=apogeeS['dist_err_x'].values[fltr],yerr=apogeeS['dist_err_y'].values[fltr],
             fmt='o',ms=3,alpha=0.2)
plt.xlim(0.,30.)
plt.ylim(0.,30.)
# Out:
# (0.0, 30.0)

# %%
plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])>4.],
           apogeeT['b_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])>4.],bins=40,norm=LogNorm());
# plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.],
#            apogeeT['b_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-453-e73e8c6df72f> in <module>()
# ----> 1 plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])>4.],
#       2            apogeeT['b_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])>4.],bins=40,norm=LogNorm());
#       3 # plt.hist2d(apogeeT['l_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.],
#       4 #            apogeeT['b_x'][np.fabs(apogeeT['dist_y']-apogeeT['dist_x'])<1.]);
#
# /home/jls/.local/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#    1220     def __getitem__(self, item):
#    1221         if isinstance(item, six.string_types):
# -> 1222             return self.columns[item]
#    1223         elif isinstance(item, (int, np.integer)):
#    1224             return self.Row(self, item)
#
# ...

# %%
plt.plot(apogeeT['log10_av_x'],apogeeT['dist_x'],'.',ms=1)
# plt.plot(np.log10(apogeeT['log10_av_y']),apogeeT['dist_y'],'.',ms=2)
plt.ylim(0.,20.)
# Out:
# (0.0, 20.0)

# %%
plt.plot(apogeeT['logg_x']-apogeeT['logg_y'],
        apogeeT['dist_x']-apogeeT['dist_y'],'.',ms=2)
plt.ylim(-5.,5.)
# Out:
# (-5.0, 5.0)

# %%
plt.hist(apogeeT['log10_av_x']-apogeeT['log10_av_y'],range=[-2.,2.],bins=40,histtype='step');
plt.semilogy()
# Out:
# []

# %%
plt.plot(np.power(10.,apogeeT['log10_age_x'])[apogeeT['logg_x']<3.1],
         np.power(10.,apogeeT['log10_age_y'])[apogeeT['logg_x']<3.1],'.',ms=2)
# plt.ylim(0.7,12.)
# plt.xlim(0.7,12.)
# xx=np.linspace(-2.,1.)
# plt.plot(xx,xx)
# plt.ylim(-2.,)
# plt.semilogy()
# plt.semilogx()

# %%
from matplotlib.colors import LogNorm

# %%
n=plt.hist2d(np.power(10.,apogee[apogee['flag']==0]['log10_teff']),
          apogee[apogee['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(apogeeI[apogee['flag']==1]['teff'],
          apogeeI[apogee['flag']==1]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
plt.hist2d(apogee['l'][apogee['flag']==1],apogee['b'][apogee['flag']==1],bins=140,norm=LogNorm());

# %%
n=plt.hist2d(np.power(10.,apogee[apogee['flag']==0]['log10_teff']),
          apogee[apogee['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(apogeeI[apogee['flag']==7]['teff'],
          apogeeI[apogee['flag']==7]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
n=plt.hist2d(np.power(10.,apogee[apogee['flag']==0]['log10_teff']),
          apogee[apogee['flag']==0]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.clf()
plt.hist2d(np.power(10.,apogee[apogee['flag']==6]['log10_teff']),
          apogee[apogee['flag']==6]['logg'],bins=50,range=[[3000.,9000.],[0.,5.5]],norm=LogNorm());
plt.contour(.5*(n[1][1:]+n[1][:-1]),.5*(n[2][1:]+n[2][:-1]),np.log10(n[0].T))
# Out:
# /data/ioasoft/software/python/2.7.8/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
plt.plot(apogee['b'][apogee['flag']==6],
         np.power(10.,apogee['log10_av'][apogee['flag']==6]),'.',ms=5)

# %%
plt.plot(np.power(10.,apogee['log10_av']),
         apogeeI['AK'],'.',ms=1)
xx = np.linspace(0.,12.)
plt.plot(xx,xx/10.)
plt.ylim(0.,2.)
# Out:
# (0.0, 2.0)
