# %%
from astropy.table import Table
from matplotlib.colors import PowerNorm
import sys
sys.path.append('scripts/')
from chemevo import chem_evo_data

# %%
apogee = Table.read('/data/jls/Downloads/apogee_astroNN-DR16.fits')

# %%
selection = (apogee['FE_H_ERR']<0.2)&(apogee['LOGG']<3.5)&(apogee['dist']<3000.)&(np.abs(apogee['GALZ'])>1.)
print(np.count_nonzero(selection))
# Out:
# 21965
# /data/jls/python3.5/site-packages/astropy/table/column.py:991: RuntimeWarning: invalid value encountered in less
#   result = getattr(super(), op)(other)
# /data/jls/python3.5/site-packages/astropy/table/column.py:991: RuntimeWarning: invalid value encountered in greater
#   result = getattr(super(), op)(other)

# %%
flS = chem_evo_data('/data/jls/out_tmp.hdf5')
ssS=np.argmin(np.abs(fl.R-8.3))
flO = chem_evo_data('/data/jls/chem_evo/results/mw_singlezone.hdf5')
ssO=np.argmin(np.abs(fl.R-8.3))
flM = chem_evo_data('/data/jls/chem_evo/results/mw_multizone.hdf5')
flM = chem_evo_data('/data/jls/out_tmp_k.hdf5')
ssM=[np.argmin(np.abs(flM.R-radii)) for radii in [4.,8.,12.]]
# Out:
# ['Ca', 'Fe', 'H', 'He', 'Mg', 'O', 'S', 'Si', 'alpha']
# ['Ca', 'Fe', 'H', 'He', 'Mg', 'O', 'S', 'Si', 'alpha']
# ['Ca', 'Fe', 'H', 'He', 'Mg', 'O', 'S', 'Si', 'alpha']
# ['Ca', 'Fe', 'H', 'He', 'Mg', 'O', 'S', 'Si', 'alpha']

# %%
elements = ['Mg','S','Si','Ca','O']
f,ax=plt.subplots(5,2,figsize=[15.,25.],sharex=True,sharey=True)
plt.subplots_adjust(hspace=0.05,wspace=0.05)

for ii,e in enumerate(elements):
    a = ax[ii]
    for kk in range(2):
        plt.sca(a[kk])
        plt.plot(flO.abund['Fe'][ssO]-flO.abund['H'][ss],
                 (flO.abund[e]-flO.abund['Fe'])[ss]+0.15,c='r')
        plt.plot(flS.abund['Fe'][ssS]-flS.abund['H'][ssS],
                 (flS.abund[e]-flS.abund['Fe'])[ssS],c='k')
        [plt.plot(flM.abund['Fe'][ssm]-flM.abund['H'][ssm],
                 (flM.abund[e]-flM.abund['Fe'])[ssm]+0.25,c='b',lw=rr+1) for rr,ssm in enumerate(ssM)]
        if ii==len(ax)-1:
            plt.xlabel(r'$\mathrm{[Fe/H]}$')
        if kk==0:
            plt.ylabel(r'$\mathrm{[%s/Fe]}$'%e)
    
    plt.sca(a[0])
    if ii==0:
        plt.title('APOGEE giants, |z|>1 kpc, s<3 kpc, logg<3.5, efeh<0.1')
    plt.hist2d(apogee['FE_H'][selection],
               (apogee['%s_H'%e.upper()]-apogee['FE_H'])[selection],
              bins=50,range=[[-1.5,0.6],[-0.1,0.4]],norm=LogNorm(),cmap=plt.cm.Spectral_r);
    plt.sca(a[1])
    plt.hexbin(apogee['FE_H'][selection],
               (apogee['%s_H'%e.upper()]-apogee['FE_H'])[selection],
               C=apogee['e'][selection],
              gridsize=30,extent=[-1.5,0.6,-0.1,0.4],cmap=plt.cm.Spectral_r,norm=PowerNorm(.5));
    plt.colorbar(label='Eccentricity')
    plt.xlim(-1.5,0.5)
    plt.ylim(-0.05,0.45)

# %% [markdown]
# ## Radial dependence

# %%
betw = lambda x,l,u: (x>l)&(x<u)
rranges = [[3,5],[7,9],[11,13]]
selectionR = [
        (apogee['FE_H_ERR']<0.2)&(apogee['LOGG']<3.5)&betw(apogee['GALR'],rd,ru)&(np.abs(apogee['GALZ'])>0.5) for rd,ru in rranges
]

f,a=plt.subplots(1,3,figsize=[15.,3.],sharex=True,sharey=True)
e='O'
for rr in range(3):
    plt.sca(a[rr])
    plt.plot(flM.abund['Fe'][ssM[rr]]-flM.abund['H'][ssM[rr]],
                 (flM.abund[e]-flM.abund['Fe'])[ssM[rr]]+0.2,c='b',lw=3)
    plt.hist2d(apogee['FE_H'][selectionR[rr]],
               (apogee['%s_H'%e.upper()]-apogee['FE_H'])[selectionR[rr]],
              bins=50,range=[[-1.5,0.6],[-0.1,0.4]],norm=LogNorm(),cmap=plt.cm.Spectral_r);
    plt.xlabel(r'$\mathrm{[Fe/H]}$')
    if rr==0:
        plt.ylabel(r'$\mathrm{[%s/Fe]}$'%e)
    plt.title('$%i<R/\mathrm{kpc}<%i$'%(rranges[rr][0],rranges[rr][1]),fontsize=15)

# %%
plt.plot(flM.Mgas.T[ssM[1]]**1.3,flM.SFR);
# plt.semilogy()
# plt.semilogx()
xx = np.linspace(100.,300.)
plt.plot(xx,xx/10.)

# %%
plt.plot(flM.t,flM.Inflow)

# %%
flM.abund
# Out:
# rec.array([[(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             ( 0.18219786,  0.33376255, -0.0023671 , -0.01702957,  0.16366573,  0.10848921,  0.21172635,  0.29664966,  0.19254576),
#             ( 0.18250967,  0.33435665, -0.00238293, -0.01701815,  0.163854  ,  0.10864684,  0.2120709 ,  0.29697827,  0.19281194),
#             ( 0.18281108,  0.33493461, -0.00239814, -0.01700727,  0.16403422,  0.10879726,  0.21240428,  0.2972959 ,  0.19306855)],
#            [(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             ( 0.17881259,  0.33358154, -0.00203754, -0.01739798,  0.15892046,  0.10356718,  0.20864238,  0.29345765,  0.18868005),
#             ( 0.17925989,  0.33437468, -0.00206152, -0.01737938,  0.1592156 ,  0.10382134,  0.20913167,  0.29392537,  0.18907077),
#             ( 0.17969596,  0.33515013, -0.00208481, -0.01736139,  0.15950196,  0.10406777,  0.20960868,  0.29438156,  0.18945119)],
#            [(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             ( 0.17631247,  0.33498588, -0.00175977, -0.01772319,  0.15475465,  0.09910821,  0.20654948,  0.29118609,  0.18558218),
#             ( 0.17691976,  0.33601056, -0.00179321, -0.01769637,  0.1551755 ,  0.09947665,  0.20720855,  0.29181815,  0.18611972),
#             ( 0.17751429,  0.33701553, -0.0018259 , -0.01767024,  0.15558601,  0.09983611,  0.20785381,  0.29243726,  0.1866455 )],
#            ...,
#            [(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             (-0.76923422, -0.76775394,  0.02621361, -0.04657252, -0.87790021, -0.90234351, -0.76916238, -0.63785211, -0.79129849),
#             (-0.77765726, -0.78044533,  0.02628   , -0.04663704, -0.88790964, -0.91347695, -0.77725448, -0.64529917, -0.8003195 ),
#             (-0.78687573, -0.79321712,  0.02634471, -0.04669925, -0.89825884, -0.92492076, -0.78614853, -0.65360696, -0.80996216)],
#            [(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             (-0.90357048, -0.96279618,  0.02701525, -0.04731312, -1.03455261, -1.07085491, -0.90129051, -0.76497679, -0.93504906),
#             (-0.91468978, -0.97646215,  0.02706051, -0.04735353, -1.04630044, -1.08372206, -0.9116199 , -0.77455064, -0.94617656),
#             (-0.92640196, -0.99012817,  0.02710457, -0.0473925 , -1.05827649, -1.09678382, -0.92264018, -0.78479722, -0.95777993)],
#            [(-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             (-3.5       , -3.        ,  0.02842992, -0.04847573, -3.5       , -3.5       , -3.5       , -3.5       , -3.5       ),
#             ...,
#             (-1.13970514, -1.28070054,  0.02775248, -0.04794451, -1.30483497, -1.35715745, -1.12665295, -0.98017778, -1.18170566),
#             (-1.15667708, -1.29502173,  0.02777575, -0.04796249, -1.31973218, -1.37294693, -1.1424487 , -0.99474894, -1.19731077),
#             (-1.17418166, -1.3093197 ,  0.02779813, -0.04797984, -1.33481406, -1.38890941, -1.15881143, -1.00989788, -1.21332289)]],
#           dtype=[('Ca', '<f8'), ('Fe', '<f8'), ('H', '<f8'), ('He', '<f8'), ('Mg', '<f8'), ('O', '<f8'), ('S', '<f8'), ('Si', '<f8'), ('alpha', '<f8')])

# %%
ages = np.linspace(1.,8.)
T = 13.7-ages
plt.plot(T,np.array(flM.paint(8.,T,['Fe'])).T);
plt.plot(flM.t,flM.Z.T[ssM[1]])

# %%
fepredict=flM.paint(apogee['rl'], apogee['age'],['Fe','O'])

# %%
plt.hist(fepredict['O_H']-fepredict['Fe_H'],bins=50,histtype='step',range=[-0.4,0.5]);
plt.hist(apogee['O_H']-apogee['FE_H'],bins=50,histtype='step',range=[-0.4,0.5]);

# %%
plt.plot(flM.SFR,flM.Mgas.T[ssM[1]]**1.4);
plt.semilogy()
