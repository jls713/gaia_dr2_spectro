# %%
data = np.genfromtxt('t')
t = data[0][1:]
r = data.T[0][1:]
dd = data[1:].T[1:].T

# %%
plt.contour(dd.T,origin='lower')

# %%
for i in range(len(dd.T)):
    plt.plot(r,dd.T[i])

# %%
for i in range(len(dd)):
    plt.plot(t,np.log10(dd[i]))

# %%
s = "0 0 0 0 0 0.0499 1.11E-6 0.14 7.19E-10 0.00428 6.59E-5 0.0163 0.0010 0.167 3.86E-4 0.0797 1.38E-4 0.0131 6.45E-5 0.00976 1.33E-7 3.94E-4 4.04E-5 0.00528 0.00672 0.761 8.29E-4 0.119 2.55E-6 3.8E-5"
spl=[float(i) for i in s.split(' ')]

# %%
np.sum(spl)
# Out:
# 1.374999593719
