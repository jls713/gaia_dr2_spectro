# %%
import sys
sys.path.append('../scripts/')
from chemevo import *

# %%
f = chem_evo_data('/data/jls/tmp.hdf5')
# Out:
# ['Ca', 'Fe', 'H', 'He', 'Mg', 'O', 'S', 'Si', 'alpha']

# %%
f.plot_time('Fe')

# %%
f.plot_time('Ca','Fe')

# %%
f.plot_elements_against_time('Fe','Ca',el_u2='Fe')
plt.xlim(-2)
plt.ylim(0.13,)
# Out:
# (0.13, 0.31581695949822164)

# %%
f.plot_elements_against_time('Fe','alpha',el_u2='Fe')
plt.xlim(-2)
plt.ylim(0.2,)
# Out:
# (0.2, 0.3924668378485107)
